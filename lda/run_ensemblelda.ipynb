# %%
# %matplotlib inline

# %% [markdown]
# Ensemble LDA
# ============
#
# Introduces Gensim's EnsembleLda model

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# This tutorial will explain how to use the EnsembleLDA model class.
#
# EnsembleLda is a method of finding and generating stable topics from the results of multiple topic models,
# it can be used to remove topics from your results that are noise and are not reproducible.

# %% [markdown]
# Corpus
# ------
# We will use the gensim downloader api to get a small corpus for training our ensemble.
#
# The preprocessing is similar to `sphx_glr_auto_examples_tutorials_run_word2vec.py`,
# so it won't be explained again in detail.

# %%
import gensim.downloader as api
from gensim.corpora import Dictionary
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
docs = api.load('text8')

dictionary = Dictionary()
for doc in docs:
    dictionary.add_documents([[lemmatizer.lemmatize(token) for token in doc]])
dictionary.filter_extremes(no_below=20, no_above=0.5)

corpus = [dictionary.doc2bow(doc) for doc in docs]
# Out:
# 2021-11-22 16:46:58,744 : INFO : adding document #0 to Dictionary<0 unique tokens: []>
# 2021-11-22 16:46:58,750 : INFO : built Dictionary<2312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1 documents (total 10000 corpus positions)
# 2021-11-22 16:46:58,778 : INFO : adding document #0 to Dictionary<2312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:58,783 : INFO : built Dictionary<3906 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 2 documents (total 20000 corpus positions)
# 2021-11-22 16:46:58,811 : INFO : adding document #0 to Dictionary<3906 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:58,816 : INFO : built Dictionary<5147 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 3 documents (total 30000 corpus positions)
# 2021-11-22 16:46:58,844 : INFO : adding document #0 to Dictionary<5147 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:58,850 : INFO : built Dictionary<6182 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 4 documents (total 40000 corpus positions)
# 2021-11-22 16:46:58,878 : INFO : adding document #0 to Dictionary<6182 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:58,883 : INFO : built Dictionary<7053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 5 documents (total 50000 corpus positions)
# 2021-11-22 16:46:58,911 : INFO : adding document #0 to Dictionary<7053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:58,917 : INFO : built Dictionary<7993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 6 documents (total 60000 corpus positions)
# 2021-11-22 16:46:58,945 : INFO : adding document #0 to Dictionary<7993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:58,950 : INFO : built Dictionary<8587 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 7 documents (total 70000 corpus positions)
# 2021-11-22 16:46:58,979 : INFO : adding document #0 to Dictionary<8587 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:58,985 : INFO : built Dictionary<9306 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 8 documents (total 80000 corpus positions)
# 2021-11-22 16:46:59,014 : INFO : adding document #0 to Dictionary<9306 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,020 : INFO : built Dictionary<10072 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 9 documents (total 90000 corpus positions)
# 2021-11-22 16:46:59,048 : INFO : adding document #0 to Dictionary<10072 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,053 : INFO : built Dictionary<10770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 10 documents (total 100000 corpus positions)
# 2021-11-22 16:46:59,081 : INFO : adding document #0 to Dictionary<10770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,087 : INFO : built Dictionary<11396 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 11 documents (total 110000 corpus positions)
# 2021-11-22 16:46:59,114 : INFO : adding document #0 to Dictionary<11396 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,120 : INFO : built Dictionary<12149 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 12 documents (total 120000 corpus positions)
# 2021-11-22 16:46:59,147 : INFO : adding document #0 to Dictionary<12149 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,153 : INFO : built Dictionary<12766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 13 documents (total 130000 corpus positions)
# 2021-11-22 16:46:59,180 : INFO : adding document #0 to Dictionary<12766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,186 : INFO : built Dictionary<13310 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 14 documents (total 140000 corpus positions)
# 2021-11-22 16:46:59,214 : INFO : adding document #0 to Dictionary<13310 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,220 : INFO : built Dictionary<13921 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 15 documents (total 150000 corpus positions)
# 2021-11-22 16:46:59,247 : INFO : adding document #0 to Dictionary<13921 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,252 : INFO : built Dictionary<14485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 16 documents (total 160000 corpus positions)
# 2021-11-22 16:46:59,280 : INFO : adding document #0 to Dictionary<14485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,285 : INFO : built Dictionary<15040 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 17 documents (total 170000 corpus positions)
# 2021-11-22 16:46:59,313 : INFO : adding document #0 to Dictionary<15040 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,318 : INFO : built Dictionary<15482 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 18 documents (total 180000 corpus positions)
# 2021-11-22 16:46:59,347 : INFO : adding document #0 to Dictionary<15482 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,352 : INFO : built Dictionary<16019 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 19 documents (total 190000 corpus positions)
# 2021-11-22 16:46:59,381 : INFO : adding document #0 to Dictionary<16019 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,387 : INFO : built Dictionary<16997 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 20 documents (total 200000 corpus positions)
# 2021-11-22 16:46:59,416 : INFO : adding document #0 to Dictionary<16997 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,421 : INFO : built Dictionary<17548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 21 documents (total 210000 corpus positions)
# 2021-11-22 16:46:59,450 : INFO : adding document #0 to Dictionary<17548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,455 : INFO : built Dictionary<18074 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 22 documents (total 220000 corpus positions)
# 2021-11-22 16:46:59,483 : INFO : adding document #0 to Dictionary<18074 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,489 : INFO : built Dictionary<18485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 23 documents (total 230000 corpus positions)
# 2021-11-22 16:46:59,517 : INFO : adding document #0 to Dictionary<18485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,523 : INFO : built Dictionary<19411 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 24 documents (total 240000 corpus positions)
# 2021-11-22 16:46:59,552 : INFO : adding document #0 to Dictionary<19411 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,558 : INFO : built Dictionary<19909 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 25 documents (total 250000 corpus positions)
# 2021-11-22 16:46:59,586 : INFO : adding document #0 to Dictionary<19909 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,591 : INFO : built Dictionary<20332 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 26 documents (total 260000 corpus positions)
# 2021-11-22 16:46:59,619 : INFO : adding document #0 to Dictionary<20332 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,626 : INFO : built Dictionary<20766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 27 documents (total 270000 corpus positions)
# 2021-11-22 16:46:59,653 : INFO : adding document #0 to Dictionary<20766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,658 : INFO : built Dictionary<21174 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 28 documents (total 280000 corpus positions)
# 2021-11-22 16:46:59,686 : INFO : adding document #0 to Dictionary<21174 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,691 : INFO : built Dictionary<21602 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 29 documents (total 290000 corpus positions)
# 2021-11-22 16:46:59,719 : INFO : adding document #0 to Dictionary<21602 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,725 : INFO : built Dictionary<21878 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 30 documents (total 300000 corpus positions)
# 2021-11-22 16:46:59,753 : INFO : adding document #0 to Dictionary<21878 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,758 : INFO : built Dictionary<22126 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 31 documents (total 310000 corpus positions)
# 2021-11-22 16:46:59,785 : INFO : adding document #0 to Dictionary<22126 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,791 : INFO : built Dictionary<22522 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 32 documents (total 320000 corpus positions)
# 2021-11-22 16:46:59,818 : INFO : adding document #0 to Dictionary<22522 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,824 : INFO : built Dictionary<23022 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 33 documents (total 330000 corpus positions)
# 2021-11-22 16:46:59,852 : INFO : adding document #0 to Dictionary<23022 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,858 : INFO : built Dictionary<23512 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 34 documents (total 340000 corpus positions)
# 2021-11-22 16:46:59,885 : INFO : adding document #0 to Dictionary<23512 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,891 : INFO : built Dictionary<24078 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 35 documents (total 350000 corpus positions)
# 2021-11-22 16:46:59,919 : INFO : adding document #0 to Dictionary<24078 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,925 : INFO : built Dictionary<24518 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 36 documents (total 360000 corpus positions)
# 2021-11-22 16:46:59,953 : INFO : adding document #0 to Dictionary<24518 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,960 : INFO : built Dictionary<25027 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 37 documents (total 370000 corpus positions)
# 2021-11-22 16:46:59,988 : INFO : adding document #0 to Dictionary<25027 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:46:59,993 : INFO : built Dictionary<25452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 38 documents (total 380000 corpus positions)
# 2021-11-22 16:47:00,022 : INFO : adding document #0 to Dictionary<25452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,028 : INFO : built Dictionary<26041 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 39 documents (total 390000 corpus positions)
# 2021-11-22 16:47:00,057 : INFO : adding document #0 to Dictionary<26041 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,063 : INFO : built Dictionary<26389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 40 documents (total 400000 corpus positions)
# 2021-11-22 16:47:00,092 : INFO : adding document #0 to Dictionary<26389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,098 : INFO : built Dictionary<26621 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 41 documents (total 410000 corpus positions)
# 2021-11-22 16:47:00,126 : INFO : adding document #0 to Dictionary<26621 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,133 : INFO : built Dictionary<27013 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 42 documents (total 420000 corpus positions)
# 2021-11-22 16:47:00,162 : INFO : adding document #0 to Dictionary<27013 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,168 : INFO : built Dictionary<27452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 43 documents (total 430000 corpus positions)
# 2021-11-22 16:47:00,196 : INFO : adding document #0 to Dictionary<27452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,202 : INFO : built Dictionary<27868 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 44 documents (total 440000 corpus positions)
# 2021-11-22 16:47:00,230 : INFO : adding document #0 to Dictionary<27868 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,236 : INFO : built Dictionary<28213 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 45 documents (total 450000 corpus positions)
# 2021-11-22 16:47:00,264 : INFO : adding document #0 to Dictionary<28213 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,270 : INFO : built Dictionary<28596 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 46 documents (total 460000 corpus positions)
# 2021-11-22 16:47:00,298 : INFO : adding document #0 to Dictionary<28596 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,303 : INFO : built Dictionary<28842 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 47 documents (total 470000 corpus positions)
# 2021-11-22 16:47:00,331 : INFO : adding document #0 to Dictionary<28842 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,337 : INFO : built Dictionary<29183 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 48 documents (total 480000 corpus positions)
# 2021-11-22 16:47:00,366 : INFO : adding document #0 to Dictionary<29183 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,372 : INFO : built Dictionary<29569 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 49 documents (total 490000 corpus positions)
# 2021-11-22 16:47:00,400 : INFO : adding document #0 to Dictionary<29569 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,407 : INFO : built Dictionary<29905 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 50 documents (total 500000 corpus positions)
# 2021-11-22 16:47:00,435 : INFO : adding document #0 to Dictionary<29905 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,443 : INFO : built Dictionary<30435 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 51 documents (total 510000 corpus positions)
# 2021-11-22 16:47:00,471 : INFO : adding document #0 to Dictionary<30435 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,478 : INFO : built Dictionary<30852 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 52 documents (total 520000 corpus positions)
# 2021-11-22 16:47:00,507 : INFO : adding document #0 to Dictionary<30852 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,513 : INFO : built Dictionary<31140 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 53 documents (total 530000 corpus positions)
# 2021-11-22 16:47:00,541 : INFO : adding document #0 to Dictionary<31140 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,547 : INFO : built Dictionary<31611 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 54 documents (total 540000 corpus positions)
# 2021-11-22 16:47:00,576 : INFO : adding document #0 to Dictionary<31611 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,584 : INFO : built Dictionary<32277 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 55 documents (total 550000 corpus positions)
# 2021-11-22 16:47:00,612 : INFO : adding document #0 to Dictionary<32277 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,619 : INFO : built Dictionary<32761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 56 documents (total 560000 corpus positions)
# 2021-11-22 16:47:00,648 : INFO : adding document #0 to Dictionary<32761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,653 : INFO : built Dictionary<33053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 57 documents (total 570000 corpus positions)
# 2021-11-22 16:47:00,683 : INFO : adding document #0 to Dictionary<33053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,689 : INFO : built Dictionary<33393 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 58 documents (total 580000 corpus positions)
# 2021-11-22 16:47:00,717 : INFO : adding document #0 to Dictionary<33393 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,723 : INFO : built Dictionary<33804 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 59 documents (total 590000 corpus positions)
# 2021-11-22 16:47:00,752 : INFO : adding document #0 to Dictionary<33804 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,759 : INFO : built Dictionary<34233 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 60 documents (total 600000 corpus positions)
# 2021-11-22 16:47:00,787 : INFO : adding document #0 to Dictionary<34233 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,793 : INFO : built Dictionary<34513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 61 documents (total 610000 corpus positions)
# 2021-11-22 16:47:00,821 : INFO : adding document #0 to Dictionary<34513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,827 : INFO : built Dictionary<34814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 62 documents (total 620000 corpus positions)
# 2021-11-22 16:47:00,855 : INFO : adding document #0 to Dictionary<34814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,861 : INFO : built Dictionary<35107 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 63 documents (total 630000 corpus positions)
# 2021-11-22 16:47:00,888 : INFO : adding document #0 to Dictionary<35107 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,895 : INFO : built Dictionary<35446 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 64 documents (total 640000 corpus positions)
# 2021-11-22 16:47:00,922 : INFO : adding document #0 to Dictionary<35446 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,928 : INFO : built Dictionary<35713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 65 documents (total 650000 corpus positions)
# 2021-11-22 16:47:00,956 : INFO : adding document #0 to Dictionary<35713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,962 : INFO : built Dictionary<36124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 66 documents (total 660000 corpus positions)
# 2021-11-22 16:47:00,990 : INFO : adding document #0 to Dictionary<36124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:00,997 : INFO : built Dictionary<36513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 67 documents (total 670000 corpus positions)
# 2021-11-22 16:47:01,025 : INFO : adding document #0 to Dictionary<36513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,031 : INFO : built Dictionary<36825 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 68 documents (total 680000 corpus positions)
# 2021-11-22 16:47:01,060 : INFO : adding document #0 to Dictionary<36825 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,066 : INFO : built Dictionary<37084 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 69 documents (total 690000 corpus positions)
# 2021-11-22 16:47:01,095 : INFO : adding document #0 to Dictionary<37084 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,101 : INFO : built Dictionary<37333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 70 documents (total 700000 corpus positions)
# 2021-11-22 16:47:01,129 : INFO : adding document #0 to Dictionary<37333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,136 : INFO : built Dictionary<37634 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 71 documents (total 710000 corpus positions)
# 2021-11-22 16:47:01,165 : INFO : adding document #0 to Dictionary<37634 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,172 : INFO : built Dictionary<37919 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 72 documents (total 720000 corpus positions)
# 2021-11-22 16:47:01,199 : INFO : adding document #0 to Dictionary<37919 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,206 : INFO : built Dictionary<38309 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 73 documents (total 730000 corpus positions)
# 2021-11-22 16:47:01,234 : INFO : adding document #0 to Dictionary<38309 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,240 : INFO : built Dictionary<38690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 74 documents (total 740000 corpus positions)
# 2021-11-22 16:47:01,269 : INFO : adding document #0 to Dictionary<38690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,276 : INFO : built Dictionary<39042 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 75 documents (total 750000 corpus positions)
# 2021-11-22 16:47:01,306 : INFO : adding document #0 to Dictionary<39042 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,312 : INFO : built Dictionary<39344 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 76 documents (total 760000 corpus positions)
# 2021-11-22 16:47:01,341 : INFO : adding document #0 to Dictionary<39344 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,347 : INFO : built Dictionary<39690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 77 documents (total 770000 corpus positions)
# 2021-11-22 16:47:01,377 : INFO : adding document #0 to Dictionary<39690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,386 : INFO : built Dictionary<40100 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 78 documents (total 780000 corpus positions)
# 2021-11-22 16:47:01,417 : INFO : adding document #0 to Dictionary<40100 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,423 : INFO : built Dictionary<40362 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 79 documents (total 790000 corpus positions)
# 2021-11-22 16:47:01,457 : INFO : adding document #0 to Dictionary<40362 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,464 : INFO : built Dictionary<40614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 80 documents (total 800000 corpus positions)
# 2021-11-22 16:47:01,494 : INFO : adding document #0 to Dictionary<40614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,502 : INFO : built Dictionary<41071 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 81 documents (total 810000 corpus positions)
# 2021-11-22 16:47:01,531 : INFO : adding document #0 to Dictionary<41071 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,538 : INFO : built Dictionary<41378 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 82 documents (total 820000 corpus positions)
# 2021-11-22 16:47:01,567 : INFO : adding document #0 to Dictionary<41378 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,573 : INFO : built Dictionary<41734 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 83 documents (total 830000 corpus positions)
# 2021-11-22 16:47:01,602 : INFO : adding document #0 to Dictionary<41734 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,609 : INFO : built Dictionary<42113 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 84 documents (total 840000 corpus positions)
# 2021-11-22 16:47:01,638 : INFO : adding document #0 to Dictionary<42113 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,645 : INFO : built Dictionary<42410 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 85 documents (total 850000 corpus positions)
# 2021-11-22 16:47:01,674 : INFO : adding document #0 to Dictionary<42410 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,682 : INFO : built Dictionary<42735 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 86 documents (total 860000 corpus positions)
# 2021-11-22 16:47:01,710 : INFO : adding document #0 to Dictionary<42735 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,718 : INFO : built Dictionary<43066 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 87 documents (total 870000 corpus positions)
# 2021-11-22 16:47:01,746 : INFO : adding document #0 to Dictionary<43066 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,753 : INFO : built Dictionary<43358 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 88 documents (total 880000 corpus positions)
# 2021-11-22 16:47:01,781 : INFO : adding document #0 to Dictionary<43358 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,792 : INFO : built Dictionary<43707 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 89 documents (total 890000 corpus positions)
# 2021-11-22 16:47:01,821 : INFO : adding document #0 to Dictionary<43707 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,829 : INFO : built Dictionary<44209 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 90 documents (total 900000 corpus positions)
# 2021-11-22 16:47:01,858 : INFO : adding document #0 to Dictionary<44209 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,865 : INFO : built Dictionary<44413 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 91 documents (total 910000 corpus positions)
# 2021-11-22 16:47:01,893 : INFO : adding document #0 to Dictionary<44413 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,900 : INFO : built Dictionary<44687 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 92 documents (total 920000 corpus positions)
# 2021-11-22 16:47:01,930 : INFO : adding document #0 to Dictionary<44687 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,938 : INFO : built Dictionary<45069 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 93 documents (total 930000 corpus positions)
# 2021-11-22 16:47:01,968 : INFO : adding document #0 to Dictionary<45069 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:01,975 : INFO : built Dictionary<45372 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 94 documents (total 940000 corpus positions)
# 2021-11-22 16:47:02,004 : INFO : adding document #0 to Dictionary<45372 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,011 : INFO : built Dictionary<45740 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 95 documents (total 950000 corpus positions)
# 2021-11-22 16:47:02,040 : INFO : adding document #0 to Dictionary<45740 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,048 : INFO : built Dictionary<46116 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 96 documents (total 960000 corpus positions)
# 2021-11-22 16:47:02,077 : INFO : adding document #0 to Dictionary<46116 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,085 : INFO : built Dictionary<46614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 97 documents (total 970000 corpus positions)
# 2021-11-22 16:47:02,113 : INFO : adding document #0 to Dictionary<46614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,121 : INFO : built Dictionary<46993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 98 documents (total 980000 corpus positions)
# 2021-11-22 16:47:02,149 : INFO : adding document #0 to Dictionary<46993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,157 : INFO : built Dictionary<47333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 99 documents (total 990000 corpus positions)
# 2021-11-22 16:47:02,184 : INFO : adding document #0 to Dictionary<47333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,192 : INFO : built Dictionary<47651 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 100 documents (total 1000000 corpus positions)
# 2021-11-22 16:47:02,219 : INFO : adding document #0 to Dictionary<47651 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,227 : INFO : built Dictionary<47971 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 101 documents (total 1010000 corpus positions)
# 2021-11-22 16:47:02,255 : INFO : adding document #0 to Dictionary<47971 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,261 : INFO : built Dictionary<48158 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 102 documents (total 1020000 corpus positions)
# 2021-11-22 16:47:02,289 : INFO : adding document #0 to Dictionary<48158 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,296 : INFO : built Dictionary<48417 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 103 documents (total 1030000 corpus positions)
# 2021-11-22 16:47:02,326 : INFO : adding document #0 to Dictionary<48417 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,333 : INFO : built Dictionary<48761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 104 documents (total 1040000 corpus positions)
# 2021-11-22 16:47:02,362 : INFO : adding document #0 to Dictionary<48761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,369 : INFO : built Dictionary<49112 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 105 documents (total 1050000 corpus positions)
# 2021-11-22 16:47:02,397 : INFO : adding document #0 to Dictionary<49112 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,404 : INFO : built Dictionary<49389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 106 documents (total 1060000 corpus positions)
# 2021-11-22 16:47:02,432 : INFO : adding document #0 to Dictionary<49389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,438 : INFO : built Dictionary<49713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 107 documents (total 1070000 corpus positions)
# 2021-11-22 16:47:02,467 : INFO : adding document #0 to Dictionary<49713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,473 : INFO : built Dictionary<50011 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 108 documents (total 1080000 corpus positions)
# 2021-11-22 16:47:02,502 : INFO : adding document #0 to Dictionary<50011 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,509 : INFO : built Dictionary<50348 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 109 documents (total 1090000 corpus positions)
# 2021-11-22 16:47:02,538 : INFO : adding document #0 to Dictionary<50348 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,545 : INFO : built Dictionary<50686 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 110 documents (total 1100000 corpus positions)
# 2021-11-22 16:47:02,573 : INFO : adding document #0 to Dictionary<50686 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,580 : INFO : built Dictionary<51015 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 111 documents (total 1110000 corpus positions)
# 2021-11-22 16:47:02,609 : INFO : adding document #0 to Dictionary<51015 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,616 : INFO : built Dictionary<51249 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 112 documents (total 1120000 corpus positions)
# 2021-11-22 16:47:02,644 : INFO : adding document #0 to Dictionary<51249 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,652 : INFO : built Dictionary<51548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 113 documents (total 1130000 corpus positions)
# 2021-11-22 16:47:02,681 : INFO : adding document #0 to Dictionary<51548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,687 : INFO : built Dictionary<51723 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 114 documents (total 1140000 corpus positions)
# 2021-11-22 16:47:02,716 : INFO : adding document #0 to Dictionary<51723 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,724 : INFO : built Dictionary<52062 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 115 documents (total 1150000 corpus positions)
# 2021-11-22 16:47:02,752 : INFO : adding document #0 to Dictionary<52062 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,760 : INFO : built Dictionary<52293 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 116 documents (total 1160000 corpus positions)
# 2021-11-22 16:47:02,789 : INFO : adding document #0 to Dictionary<52293 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,796 : INFO : built Dictionary<52463 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 117 documents (total 1170000 corpus positions)
# 2021-11-22 16:47:02,825 : INFO : adding document #0 to Dictionary<52463 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,833 : INFO : built Dictionary<52883 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 118 documents (total 1180000 corpus positions)
# 2021-11-22 16:47:02,863 : INFO : adding document #0 to Dictionary<52883 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,870 : INFO : built Dictionary<53129 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 119 documents (total 1190000 corpus positions)
# 2021-11-22 16:47:02,900 : INFO : adding document #0 to Dictionary<53129 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,907 : INFO : built Dictionary<53356 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 120 documents (total 1200000 corpus positions)
# 2021-11-22 16:47:02,936 : INFO : adding document #0 to Dictionary<53356 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,944 : INFO : built Dictionary<53643 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 121 documents (total 1210000 corpus positions)
# 2021-11-22 16:47:02,974 : INFO : adding document #0 to Dictionary<53643 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:02,982 : INFO : built Dictionary<53991 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 122 documents (total 1220000 corpus positions)
# 2021-11-22 16:47:03,011 : INFO : adding document #0 to Dictionary<53991 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,019 : INFO : built Dictionary<54237 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 123 documents (total 1230000 corpus positions)
# 2021-11-22 16:47:03,048 : INFO : adding document #0 to Dictionary<54237 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,054 : INFO : built Dictionary<54478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 124 documents (total 1240000 corpus positions)
# 2021-11-22 16:47:03,084 : INFO : adding document #0 to Dictionary<54478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,092 : INFO : built Dictionary<54729 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 125 documents (total 1250000 corpus positions)
# 2021-11-22 16:47:03,121 : INFO : adding document #0 to Dictionary<54729 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,128 : INFO : built Dictionary<54920 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 126 documents (total 1260000 corpus positions)
# 2021-11-22 16:47:03,157 : INFO : adding document #0 to Dictionary<54920 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,164 : INFO : built Dictionary<55154 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 127 documents (total 1270000 corpus positions)
# 2021-11-22 16:47:03,193 : INFO : adding document #0 to Dictionary<55154 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,200 : INFO : built Dictionary<55312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 128 documents (total 1280000 corpus positions)
# 2021-11-22 16:47:03,229 : INFO : adding document #0 to Dictionary<55312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,236 : INFO : built Dictionary<55447 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 129 documents (total 1290000 corpus positions)
# 2021-11-22 16:47:03,264 : INFO : adding document #0 to Dictionary<55447 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,271 : INFO : built Dictionary<55546 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 130 documents (total 1300000 corpus positions)
# 2021-11-22 16:47:03,299 : INFO : adding document #0 to Dictionary<55546 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,306 : INFO : built Dictionary<55725 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 131 documents (total 1310000 corpus positions)
# 2021-11-22 16:47:03,335 : INFO : adding document #0 to Dictionary<55725 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,343 : INFO : built Dictionary<55983 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 132 documents (total 1320000 corpus positions)
# 2021-11-22 16:47:03,373 : INFO : adding document #0 to Dictionary<55983 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,380 : INFO : built Dictionary<56128 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 133 documents (total 1330000 corpus positions)
# 2021-11-22 16:47:03,409 : INFO : adding document #0 to Dictionary<56128 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,416 : INFO : built Dictionary<56299 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 134 documents (total 1340000 corpus positions)
# 2021-11-22 16:47:03,445 : INFO : adding document #0 to Dictionary<56299 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,451 : INFO : built Dictionary<56401 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 135 documents (total 1350000 corpus positions)
# 2021-11-22 16:47:03,481 : INFO : adding document #0 to Dictionary<56401 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,489 : INFO : built Dictionary<56673 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 136 documents (total 1360000 corpus positions)
# 2021-11-22 16:47:03,519 : INFO : adding document #0 to Dictionary<56673 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,527 : INFO : built Dictionary<56854 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 137 documents (total 1370000 corpus positions)
# 2021-11-22 16:47:03,555 : INFO : adding document #0 to Dictionary<56854 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,561 : INFO : built Dictionary<56986 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 138 documents (total 1380000 corpus positions)
# 2021-11-22 16:47:03,590 : INFO : adding document #0 to Dictionary<56986 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,597 : INFO : built Dictionary<57177 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 139 documents (total 1390000 corpus positions)
# 2021-11-22 16:47:03,626 : INFO : adding document #0 to Dictionary<57177 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,633 : INFO : built Dictionary<57377 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 140 documents (total 1400000 corpus positions)
# 2021-11-22 16:47:03,662 : INFO : adding document #0 to Dictionary<57377 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,669 : INFO : built Dictionary<57564 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 141 documents (total 1410000 corpus positions)
# 2021-11-22 16:47:03,699 : INFO : adding document #0 to Dictionary<57564 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,707 : INFO : built Dictionary<57814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 142 documents (total 1420000 corpus positions)
# 2021-11-22 16:47:03,735 : INFO : adding document #0 to Dictionary<57814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,742 : INFO : built Dictionary<58037 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 143 documents (total 1430000 corpus positions)
# 2021-11-22 16:47:03,771 : INFO : adding document #0 to Dictionary<58037 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,777 : INFO : built Dictionary<58170 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 144 documents (total 1440000 corpus positions)
# 2021-11-22 16:47:03,806 : INFO : adding document #0 to Dictionary<58170 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,813 : INFO : built Dictionary<58427 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 145 documents (total 1450000 corpus positions)
# 2021-11-22 16:47:03,842 : INFO : adding document #0 to Dictionary<58427 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,849 : INFO : built Dictionary<58737 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 146 documents (total 1460000 corpus positions)
# 2021-11-22 16:47:03,878 : INFO : adding document #0 to Dictionary<58737 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,885 : INFO : built Dictionary<58925 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 147 documents (total 1470000 corpus positions)
# 2021-11-22 16:47:03,913 : INFO : adding document #0 to Dictionary<58925 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,921 : INFO : built Dictionary<59102 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 148 documents (total 1480000 corpus positions)
# 2021-11-22 16:47:03,949 : INFO : adding document #0 to Dictionary<59102 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,957 : INFO : built Dictionary<59274 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 149 documents (total 1490000 corpus positions)
# 2021-11-22 16:47:03,989 : INFO : adding document #0 to Dictionary<59274 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:03,996 : INFO : built Dictionary<59504 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 150 documents (total 1500000 corpus positions)
# 2021-11-22 16:47:04,026 : INFO : adding document #0 to Dictionary<59504 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:04,034 : INFO : built Dictionary<59712 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 151 documents (total 1510000 corpus positions)
# 2021-11-22 16:47:04,064 : INFO : adding document #0 to Dictionary<59712 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:04,073 : INFO : built Dictionary<60001 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 152 documents (total 1520000 corpus positions)
# 2021-11-22 16:47:04,103 : INFO : adding document #0 to Dictionary<60001 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:04,112 : INFO : built Dictionary<60298 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 153 documents (total 1530000 corpus positions)
# 2021-11-22 16:47:04,141 : INFO : adding document #0 to Dictionary<60298 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:04,150 : INFO : built Dictionary<60490 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 154 documents (total 1540000 corpus positions)
# 2021-11-22 16:47:04,181 : INFO : adding document #0 to Dictionary<60490 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# ...
# 2021-11-22 16:47:57,264 : INFO : adding document #0 to Dictionary<234598 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,271 : INFO : built Dictionary<234672 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1653 documents (total 16530000 corpus positions)
# 2021-11-22 16:47:57,299 : INFO : adding document #0 to Dictionary<234672 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,306 : INFO : built Dictionary<234770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1654 documents (total 16540000 corpus positions)
# 2021-11-22 16:47:57,334 : INFO : adding document #0 to Dictionary<234770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,341 : INFO : built Dictionary<234855 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1655 documents (total 16550000 corpus positions)
# 2021-11-22 16:47:57,369 : INFO : adding document #0 to Dictionary<234855 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,376 : INFO : built Dictionary<234937 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1656 documents (total 16560000 corpus positions)
# 2021-11-22 16:47:57,404 : INFO : adding document #0 to Dictionary<234937 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,410 : INFO : built Dictionary<235036 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1657 documents (total 16570000 corpus positions)
# 2021-11-22 16:47:57,438 : INFO : adding document #0 to Dictionary<235036 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,444 : INFO : built Dictionary<235093 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1658 documents (total 16580000 corpus positions)
# 2021-11-22 16:47:57,472 : INFO : adding document #0 to Dictionary<235093 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,478 : INFO : built Dictionary<235150 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1659 documents (total 16590000 corpus positions)
# 2021-11-22 16:47:57,508 : INFO : adding document #0 to Dictionary<235150 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,515 : INFO : built Dictionary<235224 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1660 documents (total 16600000 corpus positions)
# 2021-11-22 16:47:57,543 : INFO : adding document #0 to Dictionary<235224 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,550 : INFO : built Dictionary<235268 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1661 documents (total 16610000 corpus positions)
# 2021-11-22 16:47:57,578 : INFO : adding document #0 to Dictionary<235268 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,585 : INFO : built Dictionary<235318 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1662 documents (total 16620000 corpus positions)
# 2021-11-22 16:47:57,613 : INFO : adding document #0 to Dictionary<235318 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,619 : INFO : built Dictionary<235392 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1663 documents (total 16630000 corpus positions)
# 2021-11-22 16:47:57,648 : INFO : adding document #0 to Dictionary<235392 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,655 : INFO : built Dictionary<235471 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1664 documents (total 16640000 corpus positions)
# 2021-11-22 16:47:57,684 : INFO : adding document #0 to Dictionary<235471 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,690 : INFO : built Dictionary<235517 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1665 documents (total 16650000 corpus positions)
# 2021-11-22 16:47:57,719 : INFO : adding document #0 to Dictionary<235517 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,726 : INFO : built Dictionary<235654 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1666 documents (total 16660000 corpus positions)
# 2021-11-22 16:47:57,753 : INFO : adding document #0 to Dictionary<235654 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,762 : INFO : built Dictionary<235778 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1667 documents (total 16670000 corpus positions)
# 2021-11-22 16:47:57,790 : INFO : adding document #0 to Dictionary<235778 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,798 : INFO : built Dictionary<235926 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1668 documents (total 16680000 corpus positions)
# 2021-11-22 16:47:57,826 : INFO : adding document #0 to Dictionary<235926 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,833 : INFO : built Dictionary<236046 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1669 documents (total 16690000 corpus positions)
# 2021-11-22 16:47:57,861 : INFO : adding document #0 to Dictionary<236046 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,870 : INFO : built Dictionary<236267 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1670 documents (total 16700000 corpus positions)
# 2021-11-22 16:47:57,899 : INFO : adding document #0 to Dictionary<236267 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,906 : INFO : built Dictionary<236350 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1671 documents (total 16710000 corpus positions)
# 2021-11-22 16:47:57,935 : INFO : adding document #0 to Dictionary<236350 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,942 : INFO : built Dictionary<236474 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1672 documents (total 16720000 corpus positions)
# 2021-11-22 16:47:57,971 : INFO : adding document #0 to Dictionary<236474 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:57,977 : INFO : built Dictionary<236554 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1673 documents (total 16730000 corpus positions)
# 2021-11-22 16:47:58,006 : INFO : adding document #0 to Dictionary<236554 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,014 : INFO : built Dictionary<236726 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1674 documents (total 16740000 corpus positions)
# 2021-11-22 16:47:58,043 : INFO : adding document #0 to Dictionary<236726 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,052 : INFO : built Dictionary<236813 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1675 documents (total 16750000 corpus positions)
# 2021-11-22 16:47:58,080 : INFO : adding document #0 to Dictionary<236813 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,086 : INFO : built Dictionary<236859 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1676 documents (total 16760000 corpus positions)
# 2021-11-22 16:47:58,116 : INFO : adding document #0 to Dictionary<236859 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,123 : INFO : built Dictionary<236938 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1677 documents (total 16770000 corpus positions)
# 2021-11-22 16:47:58,152 : INFO : adding document #0 to Dictionary<236938 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,159 : INFO : built Dictionary<237039 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1678 documents (total 16780000 corpus positions)
# 2021-11-22 16:47:58,188 : INFO : adding document #0 to Dictionary<237039 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,196 : INFO : built Dictionary<237124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1679 documents (total 16790000 corpus positions)
# 2021-11-22 16:47:58,224 : INFO : adding document #0 to Dictionary<237124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,231 : INFO : built Dictionary<237163 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1680 documents (total 16800000 corpus positions)
# 2021-11-22 16:47:58,259 : INFO : adding document #0 to Dictionary<237163 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,266 : INFO : built Dictionary<237228 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1681 documents (total 16810000 corpus positions)
# 2021-11-22 16:47:58,295 : INFO : adding document #0 to Dictionary<237228 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,303 : INFO : built Dictionary<237319 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1682 documents (total 16820000 corpus positions)
# 2021-11-22 16:47:58,332 : INFO : adding document #0 to Dictionary<237319 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,339 : INFO : built Dictionary<237365 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1683 documents (total 16830000 corpus positions)
# 2021-11-22 16:47:58,368 : INFO : adding document #0 to Dictionary<237365 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,376 : INFO : built Dictionary<237475 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1684 documents (total 16840000 corpus positions)
# 2021-11-22 16:47:58,404 : INFO : adding document #0 to Dictionary<237475 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,411 : INFO : built Dictionary<237547 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1685 documents (total 16850000 corpus positions)
# 2021-11-22 16:47:58,439 : INFO : adding document #0 to Dictionary<237547 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,446 : INFO : built Dictionary<237604 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1686 documents (total 16860000 corpus positions)
# 2021-11-22 16:47:58,474 : INFO : adding document #0 to Dictionary<237604 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,482 : INFO : built Dictionary<237692 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1687 documents (total 16870000 corpus positions)
# 2021-11-22 16:47:58,511 : INFO : adding document #0 to Dictionary<237692 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,518 : INFO : built Dictionary<237745 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1688 documents (total 16880000 corpus positions)
# 2021-11-22 16:47:58,547 : INFO : adding document #0 to Dictionary<237745 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,554 : INFO : built Dictionary<237824 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1689 documents (total 16890000 corpus positions)
# 2021-11-22 16:47:58,583 : INFO : adding document #0 to Dictionary<237824 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,590 : INFO : built Dictionary<237889 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1690 documents (total 16900000 corpus positions)
# 2021-11-22 16:47:58,618 : INFO : adding document #0 to Dictionary<237889 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,625 : INFO : built Dictionary<237942 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1691 documents (total 16910000 corpus positions)
# 2021-11-22 16:47:58,653 : INFO : adding document #0 to Dictionary<237942 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,660 : INFO : built Dictionary<237985 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1692 documents (total 16920000 corpus positions)
# 2021-11-22 16:47:58,688 : INFO : adding document #0 to Dictionary<237985 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,697 : INFO : built Dictionary<238081 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1693 documents (total 16930000 corpus positions)
# 2021-11-22 16:47:58,726 : INFO : adding document #0 to Dictionary<238081 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,733 : INFO : built Dictionary<238181 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1694 documents (total 16940000 corpus positions)
# 2021-11-22 16:47:58,762 : INFO : adding document #0 to Dictionary<238181 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,770 : INFO : built Dictionary<238244 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1695 documents (total 16950000 corpus positions)
# 2021-11-22 16:47:58,799 : INFO : adding document #0 to Dictionary<238244 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,806 : INFO : built Dictionary<238315 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1696 documents (total 16960000 corpus positions)
# 2021-11-22 16:47:58,835 : INFO : adding document #0 to Dictionary<238315 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,842 : INFO : built Dictionary<238375 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1697 documents (total 16970000 corpus positions)
# 2021-11-22 16:47:58,871 : INFO : adding document #0 to Dictionary<238375 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,878 : INFO : built Dictionary<238425 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1698 documents (total 16980000 corpus positions)
# 2021-11-22 16:47:58,906 : INFO : adding document #0 to Dictionary<238425 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,912 : INFO : built Dictionary<238478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1699 documents (total 16990000 corpus positions)
# 2021-11-22 16:47:58,941 : INFO : adding document #0 to Dictionary<238478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,949 : INFO : built Dictionary<238524 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1700 documents (total 17000000 corpus positions)
# 2021-11-22 16:47:58,965 : INFO : adding document #0 to Dictionary<238524 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...>
# 2021-11-22 16:47:58,970 : INFO : built Dictionary<238542 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...> from 1701 documents (total 17005207 corpus positions)
# 2021-11-22 16:47:59,161 : INFO : discarding 218466 tokens: [('a', 1701), ('ability', 934), ('able', 1202), ('about', 1687), ('above', 1327), ('abstention', 13), ('accepted', 945), ('according', 1468), ('account', 1113), ('act', 1312)]...
# 2021-11-22 16:47:59,162 : INFO : keeping 20076 tokens which were in no less than 20 and no more than 850 (=50.0%) documents
# 2021-11-22 16:47:59,250 : INFO : resulting dictionary: Dictionary<20076 unique tokens: ['abacus', 'abnormal', 'abolished', 'abolition', 'absence']...>

# %% [markdown]
# Training
# --------
#
# Training the ensemble works very similar to training a single model,
#
# You can use any model that is based on LdaModel, such as LdaMulticore, to train the Ensemble.
# In experiments, LdaMulticore showed better results.

# %%
from gensim.models import LdaModel
topic_model_class = LdaModel

# %% [markdown]
# Any arbitrary number of models can be used, but it should be a multiple of your workers so that the
# load can be distributed properly. In this example, 4 processes will train 8 models each.

# %%
ensemble_workers = 4
num_models = 8

# %% [markdown]
# After training all the models, some distance computations are required which can take quite some
# time as well. You can speed this up by using workers for that as well.

# %%
distance_workers = 4

# %% [markdown]
# All other parameters that are unknown to EnsembleLda are forwarded to each LDA Model, such as

# %%
num_topics = 20
passes = 2

# %% [markdown]
# Now start the training
#
# Since 20 topics were trained on each of the 8 models, we expect there to be 160 different topics.
# The number of stable topics which are clustered from all those topics is smaller.

# %%
from gensim.models import EnsembleLda
ensemble = EnsembleLda(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    passes=passes,
    num_models=num_models,
    topic_model_class=LdaModel,
    ensemble_workers=ensemble_workers,
    distance_workers=distance_workers
)

print(len(ensemble.ttda))
print(len(ensemble.get_topics()))
# Out:
# 2021-11-22 16:48:27,931 : INFO : generating 8 topic models using 4 workers
# 2021-11-22 16:49:14,085 : INFO : generating a 160 x 160 asymmetric distance matrix...
# 2021-11-22 16:49:18,011 : INFO : fitting the clustering model, using 4 for min_samples
# 2021-11-22 16:49:18,036 : INFO : generating stable topics, using 3 for min_cores
# 2021-11-22 16:49:18,037 : INFO : found 1 clusters
# 2021-11-22 16:49:18,052 : INFO : found 1 stable topics
# 2021-11-22 16:49:18,056 : INFO : generating classic gensim model representation based on results from the ensemble
# 2021-11-22 16:49:18,310 : INFO : using symmetric alpha at 1.0
# 2021-11-22 16:49:18,311 : INFO : using symmetric eta at 1.0
# 2021-11-22 16:49:18,313 : INFO : using serial LDA version on this node
# 2021-11-22 16:49:18,316 : INFO : running online (multi-pass) LDA training, 1 topics, 0 passes over the supplied corpus of 1701 documents, updating model once every 1701 documents, evaluating perplexity every 1701 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-22 16:49:18,316 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-22 16:49:18,316 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=20076, num_topics=1, decay=0.5, chunksize=2000> in 0.00s', 'datetime': '2021-11-22T16:49:18.316776', 'gensim': '4.1.3.dev0', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# 160
# 1

# %%
ensemble.ttda
# Out:
# array([[5.98256975e-06, 3.22500673e-05, 5.57418243e-05, ...,
#         1.00351954e-05, 1.16328520e-05, 3.76091498e-06],
#        [1.90727969e-05, 2.31121612e-05, 7.44916833e-05, ...,
#         8.99155748e-06, 1.63097902e-05, 4.22692028e-06],
#        [7.80791652e-06, 1.02401409e-05, 1.79055540e-04, ...,
#         5.91321214e-06, 5.74727983e-06, 4.53962230e-06],
#        ...,
#        [7.37241089e-06, 3.80876772e-05, 1.51034081e-04, ...,
#         6.90094976e-06, 1.62373908e-05, 6.00045951e-06],
#        [1.96135570e-05, 2.23037132e-05, 7.49191458e-05, ...,
#         5.94797757e-06, 6.22282550e-06, 5.16965974e-06],
#        [7.38083554e-06, 2.31202539e-05, 1.15748757e-04, ...,
#         5.79557400e-06, 7.86173132e-06, 5.08735229e-06]])

# %% [markdown]
# Tuning
# ------
#
# Different from LdaModel, the number of resulting topics varies greatly depending on the clustering parameters.
#
# You can provide those in the ``recluster()`` function or the ``EnsembleLda`` constructor.
#
# Play around until you get as many topics as you desire, which however may reduce their quality.
# If your ensemble doesn't have enough topics to begin with, you should make sure to make it large enough.
#
# Having an epsilon that is smaller than the smallest distance doesn't make sense.
# Make sure to chose one that is within the range of values in ``asymmetric_distance_matrix``.

# %%
import numpy as np
shape = ensemble.asymmetric_distance_matrix.shape
without_diagonal = ensemble.asymmetric_distance_matrix[~np.eye(shape[0], dtype=bool)].reshape(shape[0], -1)
print(without_diagonal.min(), without_diagonal.mean(), without_diagonal.max())

ensemble.recluster(eps=0.07, min_samples=2, min_cores=2)

print(len(ensemble.get_topics()))
# Out:
# 2021-11-22 16:54:46,806 : INFO : fitting the clustering model
# 2021-11-22 16:54:46,830 : INFO : generating stable topics
# 2021-11-22 16:54:46,830 : INFO : found 6 clusters
# 2021-11-22 16:54:46,843 : INFO : found 1 stable topics
# 2021-11-22 16:54:46,847 : INFO : generating classic gensim model representation based on results from the ensemble
# 2021-11-22 16:54:46,849 : INFO : using symmetric alpha at 1.0
# 2021-11-22 16:54:46,849 : INFO : using symmetric eta at 1.0
# 2021-11-22 16:54:46,852 : INFO : using serial LDA version on this node
# 2021-11-22 16:54:46,854 : INFO : running online (multi-pass) LDA training, 1 topics, 0 passes over the supplied corpus of 1701 documents, updating model once every 1701 documents, evaluating perplexity every 1701 documents, iterating 50x with a convergence threshold of 0.001000
# 2021-11-22 16:54:46,854 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2021-11-22 16:54:46,855 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=20076, num_topics=1, decay=0.5, chunksize=2000> in 0.00s', 'datetime': '2021-11-22T16:54:46.855184', 'gensim': '4.1.3.dev0', 'python': '3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.19041-SP0', 'event': 'created'}
# 0.006337482145469475 0.03868349253117548 0.1346845900576048
# 1

# %% [markdown]
# Increasing the Size
# -------------------
#
# If you have some models lying around that were trained on a corpus based on the same dictionary,
# they are compatible and you can add them to the ensemble.
#
# By setting num_models of the EnsembleLda constructor to 0 you can also create an ensemble that is
# entirely made out of your existing topic models with the following method.
#
# Afterwards the number and quality of stable topics might be different depending on your added topics and parameters.

# %%
from gensim.models import LdaMulticore

model1 = LdaMulticore(
    corpus=corpus,
    id2word=dictionary,
    num_topics=9,
    passes=4,
)

model2 = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=11,
    passes=2,
)

# add_model supports various types of input, check out its docstring
ensemble.add_model(model1)
ensemble.add_model(model2)

ensemble.recluster()

print(len(ensemble.ttda))
print(len(ensemble.get_topics()))
