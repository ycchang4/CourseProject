# %%
# %matplotlib inline

# %% [markdown]
# Ensemble LDA
# ============
#
# Introduces Gensim's EnsembleLda model

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# This tutorial will explain how to use the EnsembleLDA model class.
#
# EnsembleLda is a method of finding and generating stable topics from the results of multiple topic models,
# it can be used to remove topics from your results that are noise and are not reproducible.

# %% [markdown]
# Corpus
# ------
# We will use the gensim downloader api to get a small corpus for training our ensemble.
#
# The preprocessing is similar to `sphx_glr_auto_examples_tutorials_run_word2vec.py`,
# so it won't be explained again in detail.

# %%
import gensim.downloader as api
from gensim.corpora import Dictionary
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()
docs = api.load('text8')

dictionary = Dictionary()
for doc in docs:
    dictionary.add_documents([[lemmatizer.lemmatize(token) for token in doc]])
dictionary.filter_extremes(no_below=20, no_above=0.5)

corpus = [dictionary.doc2bow(doc) for doc in docs]
# Out:
# D:\ProgramFiles\conda\lib\site-packages\gensim\similarities\__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# 2021-11-22 16:28:51,062 : INFO : adding document #0 to Dictionary(0 unique tokens: [])
# 2021-11-22 16:28:51,068 : INFO : built Dictionary(2312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1 documents (total 10000 corpus positions)
# 2021-11-22 16:28:51,095 : INFO : adding document #0 to Dictionary(2312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,101 : INFO : built Dictionary(3906 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 2 documents (total 20000 corpus positions)
# 2021-11-22 16:28:51,129 : INFO : adding document #0 to Dictionary(3906 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,134 : INFO : built Dictionary(5147 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 3 documents (total 30000 corpus positions)
# 2021-11-22 16:28:51,163 : INFO : adding document #0 to Dictionary(5147 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,168 : INFO : built Dictionary(6182 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 4 documents (total 40000 corpus positions)
# 2021-11-22 16:28:51,197 : INFO : adding document #0 to Dictionary(6182 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,202 : INFO : built Dictionary(7053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 5 documents (total 50000 corpus positions)
# 2021-11-22 16:28:51,230 : INFO : adding document #0 to Dictionary(7053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,236 : INFO : built Dictionary(7993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 6 documents (total 60000 corpus positions)
# 2021-11-22 16:28:51,263 : INFO : adding document #0 to Dictionary(7993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,269 : INFO : built Dictionary(8587 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 7 documents (total 70000 corpus positions)
# 2021-11-22 16:28:51,297 : INFO : adding document #0 to Dictionary(8587 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,302 : INFO : built Dictionary(9306 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 8 documents (total 80000 corpus positions)
# 2021-11-22 16:28:51,330 : INFO : adding document #0 to Dictionary(9306 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,336 : INFO : built Dictionary(10072 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 9 documents (total 90000 corpus positions)
# 2021-11-22 16:28:51,363 : INFO : adding document #0 to Dictionary(10072 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,369 : INFO : built Dictionary(10770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 10 documents (total 100000 corpus positions)
# 2021-11-22 16:28:51,399 : INFO : adding document #0 to Dictionary(10770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,406 : INFO : built Dictionary(11396 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 11 documents (total 110000 corpus positions)
# 2021-11-22 16:28:51,437 : INFO : adding document #0 to Dictionary(11396 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,443 : INFO : built Dictionary(12149 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 12 documents (total 120000 corpus positions)
# 2021-11-22 16:28:51,472 : INFO : adding document #0 to Dictionary(12149 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,478 : INFO : built Dictionary(12766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 13 documents (total 130000 corpus positions)
# 2021-11-22 16:28:51,508 : INFO : adding document #0 to Dictionary(12766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,514 : INFO : built Dictionary(13310 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 14 documents (total 140000 corpus positions)
# 2021-11-22 16:28:51,543 : INFO : adding document #0 to Dictionary(13310 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,549 : INFO : built Dictionary(13921 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 15 documents (total 150000 corpus positions)
# 2021-11-22 16:28:51,577 : INFO : adding document #0 to Dictionary(13921 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,583 : INFO : built Dictionary(14485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 16 documents (total 160000 corpus positions)
# 2021-11-22 16:28:51,611 : INFO : adding document #0 to Dictionary(14485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,617 : INFO : built Dictionary(15040 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 17 documents (total 170000 corpus positions)
# 2021-11-22 16:28:51,645 : INFO : adding document #0 to Dictionary(15040 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,651 : INFO : built Dictionary(15482 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 18 documents (total 180000 corpus positions)
# 2021-11-22 16:28:51,680 : INFO : adding document #0 to Dictionary(15482 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,687 : INFO : built Dictionary(16019 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 19 documents (total 190000 corpus positions)
# 2021-11-22 16:28:51,716 : INFO : adding document #0 to Dictionary(16019 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,722 : INFO : built Dictionary(16997 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 20 documents (total 200000 corpus positions)
# 2021-11-22 16:28:51,751 : INFO : adding document #0 to Dictionary(16997 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,757 : INFO : built Dictionary(17548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 21 documents (total 210000 corpus positions)
# 2021-11-22 16:28:51,786 : INFO : adding document #0 to Dictionary(17548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,792 : INFO : built Dictionary(18074 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 22 documents (total 220000 corpus positions)
# 2021-11-22 16:28:51,821 : INFO : adding document #0 to Dictionary(18074 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,827 : INFO : built Dictionary(18485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 23 documents (total 230000 corpus positions)
# 2021-11-22 16:28:51,856 : INFO : adding document #0 to Dictionary(18485 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,863 : INFO : built Dictionary(19411 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 24 documents (total 240000 corpus positions)
# 2021-11-22 16:28:51,892 : INFO : adding document #0 to Dictionary(19411 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,899 : INFO : built Dictionary(19909 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 25 documents (total 250000 corpus positions)
# 2021-11-22 16:28:51,927 : INFO : adding document #0 to Dictionary(19909 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,933 : INFO : built Dictionary(20332 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 26 documents (total 260000 corpus positions)
# 2021-11-22 16:28:51,964 : INFO : adding document #0 to Dictionary(20332 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:51,971 : INFO : built Dictionary(20766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 27 documents (total 270000 corpus positions)
# 2021-11-22 16:28:52,000 : INFO : adding document #0 to Dictionary(20766 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,006 : INFO : built Dictionary(21174 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 28 documents (total 280000 corpus positions)
# 2021-11-22 16:28:52,035 : INFO : adding document #0 to Dictionary(21174 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,041 : INFO : built Dictionary(21602 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 29 documents (total 290000 corpus positions)
# 2021-11-22 16:28:52,070 : INFO : adding document #0 to Dictionary(21602 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,077 : INFO : built Dictionary(21878 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 30 documents (total 300000 corpus positions)
# 2021-11-22 16:28:52,107 : INFO : adding document #0 to Dictionary(21878 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,113 : INFO : built Dictionary(22126 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 31 documents (total 310000 corpus positions)
# 2021-11-22 16:28:52,143 : INFO : adding document #0 to Dictionary(22126 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,150 : INFO : built Dictionary(22522 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 32 documents (total 320000 corpus positions)
# 2021-11-22 16:28:52,180 : INFO : adding document #0 to Dictionary(22522 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,188 : INFO : built Dictionary(23022 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 33 documents (total 330000 corpus positions)
# 2021-11-22 16:28:52,217 : INFO : adding document #0 to Dictionary(23022 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,224 : INFO : built Dictionary(23512 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 34 documents (total 340000 corpus positions)
# 2021-11-22 16:28:52,253 : INFO : adding document #0 to Dictionary(23512 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,261 : INFO : built Dictionary(24078 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 35 documents (total 350000 corpus positions)
# 2021-11-22 16:28:52,290 : INFO : adding document #0 to Dictionary(24078 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,298 : INFO : built Dictionary(24518 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 36 documents (total 360000 corpus positions)
# 2021-11-22 16:28:52,329 : INFO : adding document #0 to Dictionary(24518 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,337 : INFO : built Dictionary(25027 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 37 documents (total 370000 corpus positions)
# 2021-11-22 16:28:52,368 : INFO : adding document #0 to Dictionary(25027 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,374 : INFO : built Dictionary(25452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 38 documents (total 380000 corpus positions)
# 2021-11-22 16:28:52,403 : INFO : adding document #0 to Dictionary(25452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,411 : INFO : built Dictionary(26041 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 39 documents (total 390000 corpus positions)
# 2021-11-22 16:28:52,444 : INFO : adding document #0 to Dictionary(26041 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,452 : INFO : built Dictionary(26389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 40 documents (total 400000 corpus positions)
# 2021-11-22 16:28:52,481 : INFO : adding document #0 to Dictionary(26389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,488 : INFO : built Dictionary(26621 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 41 documents (total 410000 corpus positions)
# 2021-11-22 16:28:52,519 : INFO : adding document #0 to Dictionary(26621 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,527 : INFO : built Dictionary(27013 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 42 documents (total 420000 corpus positions)
# 2021-11-22 16:28:52,557 : INFO : adding document #0 to Dictionary(27013 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,564 : INFO : built Dictionary(27452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 43 documents (total 430000 corpus positions)
# 2021-11-22 16:28:52,594 : INFO : adding document #0 to Dictionary(27452 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,600 : INFO : built Dictionary(27868 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 44 documents (total 440000 corpus positions)
# 2021-11-22 16:28:52,629 : INFO : adding document #0 to Dictionary(27868 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,637 : INFO : built Dictionary(28213 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 45 documents (total 450000 corpus positions)
# 2021-11-22 16:28:52,666 : INFO : adding document #0 to Dictionary(28213 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,674 : INFO : built Dictionary(28596 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 46 documents (total 460000 corpus positions)
# 2021-11-22 16:28:52,706 : INFO : adding document #0 to Dictionary(28596 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,713 : INFO : built Dictionary(28842 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 47 documents (total 470000 corpus positions)
# 2021-11-22 16:28:52,744 : INFO : adding document #0 to Dictionary(28842 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,751 : INFO : built Dictionary(29183 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 48 documents (total 480000 corpus positions)
# 2021-11-22 16:28:52,781 : INFO : adding document #0 to Dictionary(29183 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,789 : INFO : built Dictionary(29569 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 49 documents (total 490000 corpus positions)
# 2021-11-22 16:28:52,819 : INFO : adding document #0 to Dictionary(29569 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,826 : INFO : built Dictionary(29905 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 50 documents (total 500000 corpus positions)
# 2021-11-22 16:28:52,857 : INFO : adding document #0 to Dictionary(29905 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,866 : INFO : built Dictionary(30435 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 51 documents (total 510000 corpus positions)
# 2021-11-22 16:28:52,896 : INFO : adding document #0 to Dictionary(30435 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,904 : INFO : built Dictionary(30852 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 52 documents (total 520000 corpus positions)
# 2021-11-22 16:28:52,934 : INFO : adding document #0 to Dictionary(30852 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,941 : INFO : built Dictionary(31140 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 53 documents (total 530000 corpus positions)
# 2021-11-22 16:28:52,971 : INFO : adding document #0 to Dictionary(31140 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:52,980 : INFO : built Dictionary(31611 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 54 documents (total 540000 corpus positions)
# 2021-11-22 16:28:53,012 : INFO : adding document #0 to Dictionary(31611 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,018 : INFO : built Dictionary(32277 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 55 documents (total 550000 corpus positions)
# 2021-11-22 16:28:53,048 : INFO : adding document #0 to Dictionary(32277 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,055 : INFO : built Dictionary(32761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 56 documents (total 560000 corpus positions)
# 2021-11-22 16:28:53,084 : INFO : adding document #0 to Dictionary(32761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,090 : INFO : built Dictionary(33053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 57 documents (total 570000 corpus positions)
# 2021-11-22 16:28:53,120 : INFO : adding document #0 to Dictionary(33053 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,127 : INFO : built Dictionary(33393 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 58 documents (total 580000 corpus positions)
# 2021-11-22 16:28:53,156 : INFO : adding document #0 to Dictionary(33393 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,164 : INFO : built Dictionary(33804 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 59 documents (total 590000 corpus positions)
# 2021-11-22 16:28:53,194 : INFO : adding document #0 to Dictionary(33804 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,201 : INFO : built Dictionary(34233 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 60 documents (total 600000 corpus positions)
# 2021-11-22 16:28:53,230 : INFO : adding document #0 to Dictionary(34233 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,237 : INFO : built Dictionary(34513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 61 documents (total 610000 corpus positions)
# 2021-11-22 16:28:53,267 : INFO : adding document #0 to Dictionary(34513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,273 : INFO : built Dictionary(34814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 62 documents (total 620000 corpus positions)
# 2021-11-22 16:28:53,302 : INFO : adding document #0 to Dictionary(34814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,309 : INFO : built Dictionary(35107 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 63 documents (total 630000 corpus positions)
# 2021-11-22 16:28:53,339 : INFO : adding document #0 to Dictionary(35107 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,347 : INFO : built Dictionary(35446 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 64 documents (total 640000 corpus positions)
# 2021-11-22 16:28:53,378 : INFO : adding document #0 to Dictionary(35446 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,385 : INFO : built Dictionary(35713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 65 documents (total 650000 corpus positions)
# 2021-11-22 16:28:53,416 : INFO : adding document #0 to Dictionary(35713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,425 : INFO : built Dictionary(36124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 66 documents (total 660000 corpus positions)
# 2021-11-22 16:28:53,457 : INFO : adding document #0 to Dictionary(36124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,464 : INFO : built Dictionary(36513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 67 documents (total 670000 corpus positions)
# 2021-11-22 16:28:53,494 : INFO : adding document #0 to Dictionary(36513 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,501 : INFO : built Dictionary(36825 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 68 documents (total 680000 corpus positions)
# 2021-11-22 16:28:53,530 : INFO : adding document #0 to Dictionary(36825 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,537 : INFO : built Dictionary(37084 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 69 documents (total 690000 corpus positions)
# 2021-11-22 16:28:53,567 : INFO : adding document #0 to Dictionary(37084 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,573 : INFO : built Dictionary(37333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 70 documents (total 700000 corpus positions)
# 2021-11-22 16:28:53,604 : INFO : adding document #0 to Dictionary(37333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,612 : INFO : built Dictionary(37634 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 71 documents (total 710000 corpus positions)
# 2021-11-22 16:28:53,641 : INFO : adding document #0 to Dictionary(37634 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,648 : INFO : built Dictionary(37919 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 72 documents (total 720000 corpus positions)
# 2021-11-22 16:28:53,676 : INFO : adding document #0 to Dictionary(37919 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,683 : INFO : built Dictionary(38309 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 73 documents (total 730000 corpus positions)
# 2021-11-22 16:28:53,712 : INFO : adding document #0 to Dictionary(38309 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,720 : INFO : built Dictionary(38690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 74 documents (total 740000 corpus positions)
# 2021-11-22 16:28:53,749 : INFO : adding document #0 to Dictionary(38690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,756 : INFO : built Dictionary(39042 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 75 documents (total 750000 corpus positions)
# 2021-11-22 16:28:53,787 : INFO : adding document #0 to Dictionary(39042 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,793 : INFO : built Dictionary(39344 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 76 documents (total 760000 corpus positions)
# 2021-11-22 16:28:53,822 : INFO : adding document #0 to Dictionary(39344 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,828 : INFO : built Dictionary(39690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 77 documents (total 770000 corpus positions)
# 2021-11-22 16:28:53,858 : INFO : adding document #0 to Dictionary(39690 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,865 : INFO : built Dictionary(40100 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 78 documents (total 780000 corpus positions)
# 2021-11-22 16:28:53,894 : INFO : adding document #0 to Dictionary(40100 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,901 : INFO : built Dictionary(40362 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 79 documents (total 790000 corpus positions)
# 2021-11-22 16:28:53,931 : INFO : adding document #0 to Dictionary(40362 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,939 : INFO : built Dictionary(40614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 80 documents (total 800000 corpus positions)
# 2021-11-22 16:28:53,970 : INFO : adding document #0 to Dictionary(40614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:53,978 : INFO : built Dictionary(41071 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 81 documents (total 810000 corpus positions)
# 2021-11-22 16:28:54,008 : INFO : adding document #0 to Dictionary(41071 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,015 : INFO : built Dictionary(41378 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 82 documents (total 820000 corpus positions)
# 2021-11-22 16:28:54,045 : INFO : adding document #0 to Dictionary(41378 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,052 : INFO : built Dictionary(41734 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 83 documents (total 830000 corpus positions)
# 2021-11-22 16:28:54,082 : INFO : adding document #0 to Dictionary(41734 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,089 : INFO : built Dictionary(42113 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 84 documents (total 840000 corpus positions)
# 2021-11-22 16:28:54,118 : INFO : adding document #0 to Dictionary(42113 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,125 : INFO : built Dictionary(42410 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 85 documents (total 850000 corpus positions)
# 2021-11-22 16:28:54,154 : INFO : adding document #0 to Dictionary(42410 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,161 : INFO : built Dictionary(42735 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 86 documents (total 860000 corpus positions)
# 2021-11-22 16:28:54,189 : INFO : adding document #0 to Dictionary(42735 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,196 : INFO : built Dictionary(43066 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 87 documents (total 870000 corpus positions)
# 2021-11-22 16:28:54,224 : INFO : adding document #0 to Dictionary(43066 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,230 : INFO : built Dictionary(43358 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 88 documents (total 880000 corpus positions)
# 2021-11-22 16:28:54,258 : INFO : adding document #0 to Dictionary(43358 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,267 : INFO : built Dictionary(43707 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 89 documents (total 890000 corpus positions)
# 2021-11-22 16:28:54,296 : INFO : adding document #0 to Dictionary(43707 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,302 : INFO : built Dictionary(44209 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 90 documents (total 900000 corpus positions)
# 2021-11-22 16:28:54,330 : INFO : adding document #0 to Dictionary(44209 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,336 : INFO : built Dictionary(44413 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 91 documents (total 910000 corpus positions)
# 2021-11-22 16:28:54,364 : INFO : adding document #0 to Dictionary(44413 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,370 : INFO : built Dictionary(44687 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 92 documents (total 920000 corpus positions)
# 2021-11-22 16:28:54,399 : INFO : adding document #0 to Dictionary(44687 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,406 : INFO : built Dictionary(45069 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 93 documents (total 930000 corpus positions)
# 2021-11-22 16:28:54,434 : INFO : adding document #0 to Dictionary(45069 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,441 : INFO : built Dictionary(45372 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 94 documents (total 940000 corpus positions)
# 2021-11-22 16:28:54,470 : INFO : adding document #0 to Dictionary(45372 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,477 : INFO : built Dictionary(45740 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 95 documents (total 950000 corpus positions)
# 2021-11-22 16:28:54,506 : INFO : adding document #0 to Dictionary(45740 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,514 : INFO : built Dictionary(46116 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 96 documents (total 960000 corpus positions)
# 2021-11-22 16:28:54,546 : INFO : adding document #0 to Dictionary(46116 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,552 : INFO : built Dictionary(46614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 97 documents (total 970000 corpus positions)
# 2021-11-22 16:28:54,581 : INFO : adding document #0 to Dictionary(46614 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,589 : INFO : built Dictionary(46993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 98 documents (total 980000 corpus positions)
# 2021-11-22 16:28:54,618 : INFO : adding document #0 to Dictionary(46993 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,624 : INFO : built Dictionary(47333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 99 documents (total 990000 corpus positions)
# 2021-11-22 16:28:54,653 : INFO : adding document #0 to Dictionary(47333 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,659 : INFO : built Dictionary(47651 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 100 documents (total 1000000 corpus positions)
# 2021-11-22 16:28:54,687 : INFO : adding document #0 to Dictionary(47651 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,694 : INFO : built Dictionary(47971 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 101 documents (total 1010000 corpus positions)
# 2021-11-22 16:28:54,723 : INFO : adding document #0 to Dictionary(47971 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,729 : INFO : built Dictionary(48158 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 102 documents (total 1020000 corpus positions)
# 2021-11-22 16:28:54,759 : INFO : adding document #0 to Dictionary(48158 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,765 : INFO : built Dictionary(48417 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 103 documents (total 1030000 corpus positions)
# 2021-11-22 16:28:54,796 : INFO : adding document #0 to Dictionary(48417 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,803 : INFO : built Dictionary(48761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 104 documents (total 1040000 corpus positions)
# 2021-11-22 16:28:54,832 : INFO : adding document #0 to Dictionary(48761 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,839 : INFO : built Dictionary(49112 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 105 documents (total 1050000 corpus positions)
# 2021-11-22 16:28:54,867 : INFO : adding document #0 to Dictionary(49112 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,873 : INFO : built Dictionary(49389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 106 documents (total 1060000 corpus positions)
# 2021-11-22 16:28:54,901 : INFO : adding document #0 to Dictionary(49389 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,906 : INFO : built Dictionary(49713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 107 documents (total 1070000 corpus positions)
# 2021-11-22 16:28:54,935 : INFO : adding document #0 to Dictionary(49713 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,942 : INFO : built Dictionary(50011 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 108 documents (total 1080000 corpus positions)
# 2021-11-22 16:28:54,971 : INFO : adding document #0 to Dictionary(50011 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:54,979 : INFO : built Dictionary(50348 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 109 documents (total 1090000 corpus positions)
# 2021-11-22 16:28:55,007 : INFO : adding document #0 to Dictionary(50348 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,014 : INFO : built Dictionary(50686 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 110 documents (total 1100000 corpus positions)
# 2021-11-22 16:28:55,042 : INFO : adding document #0 to Dictionary(50686 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,049 : INFO : built Dictionary(51015 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 111 documents (total 1110000 corpus positions)
# 2021-11-22 16:28:55,078 : INFO : adding document #0 to Dictionary(51015 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,085 : INFO : built Dictionary(51249 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 112 documents (total 1120000 corpus positions)
# 2021-11-22 16:28:55,116 : INFO : adding document #0 to Dictionary(51249 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,124 : INFO : built Dictionary(51548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 113 documents (total 1130000 corpus positions)
# 2021-11-22 16:28:55,154 : INFO : adding document #0 to Dictionary(51548 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,161 : INFO : built Dictionary(51723 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 114 documents (total 1140000 corpus positions)
# 2021-11-22 16:28:55,191 : INFO : adding document #0 to Dictionary(51723 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,200 : INFO : built Dictionary(52062 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 115 documents (total 1150000 corpus positions)
# 2021-11-22 16:28:55,230 : INFO : adding document #0 to Dictionary(52062 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,240 : INFO : built Dictionary(52293 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 116 documents (total 1160000 corpus positions)
# 2021-11-22 16:28:55,271 : INFO : adding document #0 to Dictionary(52293 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,278 : INFO : built Dictionary(52463 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 117 documents (total 1170000 corpus positions)
# 2021-11-22 16:28:55,308 : INFO : adding document #0 to Dictionary(52463 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,317 : INFO : built Dictionary(52883 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 118 documents (total 1180000 corpus positions)
# 2021-11-22 16:28:55,348 : INFO : adding document #0 to Dictionary(52883 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,355 : INFO : built Dictionary(53129 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 119 documents (total 1190000 corpus positions)
# 2021-11-22 16:28:55,390 : INFO : adding document #0 to Dictionary(53129 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,399 : INFO : built Dictionary(53356 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 120 documents (total 1200000 corpus positions)
# 2021-11-22 16:28:55,429 : INFO : adding document #0 to Dictionary(53356 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,437 : INFO : built Dictionary(53643 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 121 documents (total 1210000 corpus positions)
# 2021-11-22 16:28:55,467 : INFO : adding document #0 to Dictionary(53643 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,475 : INFO : built Dictionary(53991 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 122 documents (total 1220000 corpus positions)
# 2021-11-22 16:28:55,504 : INFO : adding document #0 to Dictionary(53991 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,510 : INFO : built Dictionary(54237 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 123 documents (total 1230000 corpus positions)
# 2021-11-22 16:28:55,539 : INFO : adding document #0 to Dictionary(54237 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,545 : INFO : built Dictionary(54478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 124 documents (total 1240000 corpus positions)
# 2021-11-22 16:28:55,574 : INFO : adding document #0 to Dictionary(54478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,581 : INFO : built Dictionary(54729 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 125 documents (total 1250000 corpus positions)
# 2021-11-22 16:28:55,610 : INFO : adding document #0 to Dictionary(54729 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,617 : INFO : built Dictionary(54920 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 126 documents (total 1260000 corpus positions)
# 2021-11-22 16:28:55,646 : INFO : adding document #0 to Dictionary(54920 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,652 : INFO : built Dictionary(55154 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 127 documents (total 1270000 corpus positions)
# 2021-11-22 16:28:55,681 : INFO : adding document #0 to Dictionary(55154 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,687 : INFO : built Dictionary(55312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 128 documents (total 1280000 corpus positions)
# 2021-11-22 16:28:55,716 : INFO : adding document #0 to Dictionary(55312 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,723 : INFO : built Dictionary(55447 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 129 documents (total 1290000 corpus positions)
# 2021-11-22 16:28:55,752 : INFO : adding document #0 to Dictionary(55447 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,758 : INFO : built Dictionary(55546 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 130 documents (total 1300000 corpus positions)
# 2021-11-22 16:28:55,787 : INFO : adding document #0 to Dictionary(55546 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,793 : INFO : built Dictionary(55725 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 131 documents (total 1310000 corpus positions)
# 2021-11-22 16:28:55,823 : INFO : adding document #0 to Dictionary(55725 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,831 : INFO : built Dictionary(55983 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 132 documents (total 1320000 corpus positions)
# 2021-11-22 16:28:55,860 : INFO : adding document #0 to Dictionary(55983 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,867 : INFO : built Dictionary(56128 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 133 documents (total 1330000 corpus positions)
# 2021-11-22 16:28:55,899 : INFO : adding document #0 to Dictionary(56128 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,906 : INFO : built Dictionary(56299 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 134 documents (total 1340000 corpus positions)
# 2021-11-22 16:28:55,934 : INFO : adding document #0 to Dictionary(56299 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,940 : INFO : built Dictionary(56401 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 135 documents (total 1350000 corpus positions)
# 2021-11-22 16:28:55,970 : INFO : adding document #0 to Dictionary(56401 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:55,977 : INFO : built Dictionary(56673 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 136 documents (total 1360000 corpus positions)
# 2021-11-22 16:28:56,006 : INFO : adding document #0 to Dictionary(56673 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,013 : INFO : built Dictionary(56854 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 137 documents (total 1370000 corpus positions)
# 2021-11-22 16:28:56,043 : INFO : adding document #0 to Dictionary(56854 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,049 : INFO : built Dictionary(56986 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 138 documents (total 1380000 corpus positions)
# 2021-11-22 16:28:56,078 : INFO : adding document #0 to Dictionary(56986 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,084 : INFO : built Dictionary(57177 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 139 documents (total 1390000 corpus positions)
# 2021-11-22 16:28:56,113 : INFO : adding document #0 to Dictionary(57177 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,120 : INFO : built Dictionary(57377 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 140 documents (total 1400000 corpus positions)
# 2021-11-22 16:28:56,149 : INFO : adding document #0 to Dictionary(57377 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,155 : INFO : built Dictionary(57564 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 141 documents (total 1410000 corpus positions)
# 2021-11-22 16:28:56,186 : INFO : adding document #0 to Dictionary(57564 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,194 : INFO : built Dictionary(57814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 142 documents (total 1420000 corpus positions)
# 2021-11-22 16:28:56,222 : INFO : adding document #0 to Dictionary(57814 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,228 : INFO : built Dictionary(58037 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 143 documents (total 1430000 corpus positions)
# 2021-11-22 16:28:56,257 : INFO : adding document #0 to Dictionary(58037 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,263 : INFO : built Dictionary(58170 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 144 documents (total 1440000 corpus positions)
# 2021-11-22 16:28:56,293 : INFO : adding document #0 to Dictionary(58170 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,300 : INFO : built Dictionary(58427 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 145 documents (total 1450000 corpus positions)
# 2021-11-22 16:28:56,330 : INFO : adding document #0 to Dictionary(58427 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,337 : INFO : built Dictionary(58737 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 146 documents (total 1460000 corpus positions)
# 2021-11-22 16:28:56,368 : INFO : adding document #0 to Dictionary(58737 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,375 : INFO : built Dictionary(58925 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 147 documents (total 1470000 corpus positions)
# 2021-11-22 16:28:56,404 : INFO : adding document #0 to Dictionary(58925 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,412 : INFO : built Dictionary(59102 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 148 documents (total 1480000 corpus positions)
# 2021-11-22 16:28:56,443 : INFO : adding document #0 to Dictionary(59102 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,450 : INFO : built Dictionary(59274 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 149 documents (total 1490000 corpus positions)
# 2021-11-22 16:28:56,482 : INFO : adding document #0 to Dictionary(59274 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,488 : INFO : built Dictionary(59504 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 150 documents (total 1500000 corpus positions)
# 2021-11-22 16:28:56,519 : INFO : adding document #0 to Dictionary(59504 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,526 : INFO : built Dictionary(59712 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 151 documents (total 1510000 corpus positions)
# 2021-11-22 16:28:56,557 : INFO : adding document #0 to Dictionary(59712 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,565 : INFO : built Dictionary(60001 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 152 documents (total 1520000 corpus positions)
# 2021-11-22 16:28:56,595 : INFO : adding document #0 to Dictionary(60001 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:28:56,603 : INFO : built Dictionary(60298 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 153 documents (total 1530000 corpus positions)
# 2021-11-22 16:28:56,633 : INFO : adding document #0 to Dictionary(60298 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# ...
# 2021-11-22 16:29:52,556 : INFO : adding document #0 to Dictionary(234598 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,562 : INFO : built Dictionary(234672 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1653 documents (total 16530000 corpus positions)
# 2021-11-22 16:29:52,591 : INFO : adding document #0 to Dictionary(234672 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,597 : INFO : built Dictionary(234770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1654 documents (total 16540000 corpus positions)
# 2021-11-22 16:29:52,626 : INFO : adding document #0 to Dictionary(234770 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,632 : INFO : built Dictionary(234855 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1655 documents (total 16550000 corpus positions)
# 2021-11-22 16:29:52,660 : INFO : adding document #0 to Dictionary(234855 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,668 : INFO : built Dictionary(234937 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1656 documents (total 16560000 corpus positions)
# 2021-11-22 16:29:52,700 : INFO : adding document #0 to Dictionary(234937 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,707 : INFO : built Dictionary(235036 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1657 documents (total 16570000 corpus positions)
# 2021-11-22 16:29:52,746 : INFO : adding document #0 to Dictionary(235036 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,752 : INFO : built Dictionary(235093 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1658 documents (total 16580000 corpus positions)
# 2021-11-22 16:29:52,781 : INFO : adding document #0 to Dictionary(235093 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,790 : INFO : built Dictionary(235150 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1659 documents (total 16590000 corpus positions)
# 2021-11-22 16:29:52,819 : INFO : adding document #0 to Dictionary(235150 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,827 : INFO : built Dictionary(235224 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1660 documents (total 16600000 corpus positions)
# 2021-11-22 16:29:52,855 : INFO : adding document #0 to Dictionary(235224 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,863 : INFO : built Dictionary(235268 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1661 documents (total 16610000 corpus positions)
# 2021-11-22 16:29:52,894 : INFO : adding document #0 to Dictionary(235268 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,900 : INFO : built Dictionary(235318 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1662 documents (total 16620000 corpus positions)
# 2021-11-22 16:29:52,929 : INFO : adding document #0 to Dictionary(235318 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,935 : INFO : built Dictionary(235392 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1663 documents (total 16630000 corpus positions)
# 2021-11-22 16:29:52,966 : INFO : adding document #0 to Dictionary(235392 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:52,973 : INFO : built Dictionary(235471 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1664 documents (total 16640000 corpus positions)
# 2021-11-22 16:29:53,005 : INFO : adding document #0 to Dictionary(235471 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,011 : INFO : built Dictionary(235517 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1665 documents (total 16650000 corpus positions)
# 2021-11-22 16:29:53,040 : INFO : adding document #0 to Dictionary(235517 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,047 : INFO : built Dictionary(235654 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1666 documents (total 16660000 corpus positions)
# 2021-11-22 16:29:53,075 : INFO : adding document #0 to Dictionary(235654 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,081 : INFO : built Dictionary(235778 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1667 documents (total 16670000 corpus positions)
# 2021-11-22 16:29:53,110 : INFO : adding document #0 to Dictionary(235778 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,117 : INFO : built Dictionary(235926 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1668 documents (total 16680000 corpus positions)
# 2021-11-22 16:29:53,145 : INFO : adding document #0 to Dictionary(235926 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,152 : INFO : built Dictionary(236046 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1669 documents (total 16690000 corpus positions)
# 2021-11-22 16:29:53,180 : INFO : adding document #0 to Dictionary(236046 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,189 : INFO : built Dictionary(236267 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1670 documents (total 16700000 corpus positions)
# 2021-11-22 16:29:53,218 : INFO : adding document #0 to Dictionary(236267 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,225 : INFO : built Dictionary(236350 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1671 documents (total 16710000 corpus positions)
# 2021-11-22 16:29:53,254 : INFO : adding document #0 to Dictionary(236350 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,260 : INFO : built Dictionary(236474 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1672 documents (total 16720000 corpus positions)
# 2021-11-22 16:29:53,289 : INFO : adding document #0 to Dictionary(236474 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,296 : INFO : built Dictionary(236554 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1673 documents (total 16730000 corpus positions)
# 2021-11-22 16:29:53,326 : INFO : adding document #0 to Dictionary(236554 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,334 : INFO : built Dictionary(236726 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1674 documents (total 16740000 corpus positions)
# 2021-11-22 16:29:53,363 : INFO : adding document #0 to Dictionary(236726 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,372 : INFO : built Dictionary(236813 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1675 documents (total 16750000 corpus positions)
# 2021-11-22 16:29:53,401 : INFO : adding document #0 to Dictionary(236813 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,408 : INFO : built Dictionary(236859 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1676 documents (total 16760000 corpus positions)
# 2021-11-22 16:29:53,438 : INFO : adding document #0 to Dictionary(236859 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,445 : INFO : built Dictionary(236938 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1677 documents (total 16770000 corpus positions)
# 2021-11-22 16:29:53,474 : INFO : adding document #0 to Dictionary(236938 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,480 : INFO : built Dictionary(237039 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1678 documents (total 16780000 corpus positions)
# 2021-11-22 16:29:53,509 : INFO : adding document #0 to Dictionary(237039 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,516 : INFO : built Dictionary(237124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1679 documents (total 16790000 corpus positions)
# 2021-11-22 16:29:53,544 : INFO : adding document #0 to Dictionary(237124 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,550 : INFO : built Dictionary(237163 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1680 documents (total 16800000 corpus positions)
# 2021-11-22 16:29:53,579 : INFO : adding document #0 to Dictionary(237163 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,585 : INFO : built Dictionary(237228 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1681 documents (total 16810000 corpus positions)
# 2021-11-22 16:29:53,613 : INFO : adding document #0 to Dictionary(237228 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,620 : INFO : built Dictionary(237319 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1682 documents (total 16820000 corpus positions)
# 2021-11-22 16:29:53,649 : INFO : adding document #0 to Dictionary(237319 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,657 : INFO : built Dictionary(237365 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1683 documents (total 16830000 corpus positions)
# 2021-11-22 16:29:53,685 : INFO : adding document #0 to Dictionary(237365 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,692 : INFO : built Dictionary(237475 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1684 documents (total 16840000 corpus positions)
# 2021-11-22 16:29:53,720 : INFO : adding document #0 to Dictionary(237475 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,726 : INFO : built Dictionary(237547 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1685 documents (total 16850000 corpus positions)
# 2021-11-22 16:29:53,755 : INFO : adding document #0 to Dictionary(237547 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,762 : INFO : built Dictionary(237604 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1686 documents (total 16860000 corpus positions)
# 2021-11-22 16:29:53,790 : INFO : adding document #0 to Dictionary(237604 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,798 : INFO : built Dictionary(237692 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1687 documents (total 16870000 corpus positions)
# 2021-11-22 16:29:53,826 : INFO : adding document #0 to Dictionary(237692 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,833 : INFO : built Dictionary(237745 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1688 documents (total 16880000 corpus positions)
# 2021-11-22 16:29:53,862 : INFO : adding document #0 to Dictionary(237745 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,869 : INFO : built Dictionary(237824 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1689 documents (total 16890000 corpus positions)
# 2021-11-22 16:29:53,898 : INFO : adding document #0 to Dictionary(237824 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,905 : INFO : built Dictionary(237889 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1690 documents (total 16900000 corpus positions)
# 2021-11-22 16:29:53,935 : INFO : adding document #0 to Dictionary(237889 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,941 : INFO : built Dictionary(237942 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1691 documents (total 16910000 corpus positions)
# 2021-11-22 16:29:53,970 : INFO : adding document #0 to Dictionary(237942 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:53,977 : INFO : built Dictionary(237985 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1692 documents (total 16920000 corpus positions)
# 2021-11-22 16:29:54,008 : INFO : adding document #0 to Dictionary(237985 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,016 : INFO : built Dictionary(238081 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1693 documents (total 16930000 corpus positions)
# 2021-11-22 16:29:54,044 : INFO : adding document #0 to Dictionary(238081 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,051 : INFO : built Dictionary(238181 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1694 documents (total 16940000 corpus positions)
# 2021-11-22 16:29:54,080 : INFO : adding document #0 to Dictionary(238181 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,087 : INFO : built Dictionary(238244 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1695 documents (total 16950000 corpus positions)
# 2021-11-22 16:29:54,116 : INFO : adding document #0 to Dictionary(238244 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,123 : INFO : built Dictionary(238315 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1696 documents (total 16960000 corpus positions)
# 2021-11-22 16:29:54,152 : INFO : adding document #0 to Dictionary(238315 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,159 : INFO : built Dictionary(238375 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1697 documents (total 16970000 corpus positions)
# 2021-11-22 16:29:54,189 : INFO : adding document #0 to Dictionary(238375 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,196 : INFO : built Dictionary(238425 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1698 documents (total 16980000 corpus positions)
# 2021-11-22 16:29:54,224 : INFO : adding document #0 to Dictionary(238425 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,231 : INFO : built Dictionary(238478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1699 documents (total 16990000 corpus positions)
# 2021-11-22 16:29:54,260 : INFO : adding document #0 to Dictionary(238478 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,268 : INFO : built Dictionary(238524 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1700 documents (total 17000000 corpus positions)
# 2021-11-22 16:29:54,283 : INFO : adding document #0 to Dictionary(238524 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...)
# 2021-11-22 16:29:54,287 : INFO : built Dictionary(238542 unique tokens: ['a', 'abacus', 'ability', 'able', 'abnormal']...) from 1701 documents (total 17005207 corpus positions)
# 2021-11-22 16:29:54,492 : INFO : discarding 218466 tokens: [('a', 1701), ('ability', 934), ('able', 1202), ('about', 1687), ('above', 1327), ('abstention', 13), ('accepted', 945), ('according', 1468), ('account', 1113), ('act', 1312)]...
# 2021-11-22 16:29:54,492 : INFO : keeping 20076 tokens which were in no less than 20 and no more than 850 (=50.0%) documents
# 2021-11-22 16:29:54,590 : INFO : resulting dictionary: Dictionary(20076 unique tokens: ['abacus', 'abnormal', 'abolished', 'abolition', 'absence']...)

# %% [markdown]
# Training
# --------
#
# Training the ensemble works very similar to training a single model,
#
# You can use any model that is based on LdaModel, such as LdaMulticore, to train the Ensemble.
# In experiments, LdaMulticore showed better results.

# %%
from gensim.models import LdaModel
topic_model_class = LdaModel

# %% [markdown]
# Any arbitrary number of models can be used, but it should be a multiple of your workers so that the
# load can be distributed properly. In this example, 4 processes will train 8 models each.

# %%
ensemble_workers = 4
num_models = 8

# %% [markdown]
# After training all the models, some distance computations are required which can take quite some
# time as well. You can speed this up by using workers for that as well.

# %%
distance_workers = 4

# %% [markdown]
# All other parameters that are unknown to EnsembleLda are forwarded to each LDA Model, such as

# %%
num_topics = 20
passes = 2

# %% [markdown]
# Now start the training
#
# Since 20 topics were trained on each of the 8 models, we expect there to be 160 different topics.
# The number of stable topics which are clustered from all those topics is smaller.

# %%
from gensim.models import EnsembleLda
ensemble = EnsembleLda(
    corpus=corpus,
    id2word=dictionary,
    num_topics=num_topics,
    passes=passes,
    num_models=num_models,
    topic_model_class=LdaModel,
    ensemble_workers=ensemble_workers,
    distance_workers=distance_workers
)

print(len(ensemble.ttda))
print(len(ensemble.get_topics()))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-9afa14b441d9> in <module>
# ----> 1 from gensim.models import EnsembleLda
#       2 ensemble = EnsembleLda(
#       3     corpus=corpus,
#       4     id2word=dictionary,
#       5     num_topics=num_topics,
#
# ImportError: cannot import name 'EnsembleLda' from 'gensim.models' (D:\ProgramFiles\conda\lib\site-packages\gensim\models\__init__.py)

# %% [markdown]
# Tuning
# ------
#
# Different from LdaModel, the number of resulting topics varies greatly depending on the clustering parameters.
#
# You can provide those in the ``recluster()`` function or the ``EnsembleLda`` constructor.
#
# Play around until you get as many topics as you desire, which however may reduce their quality.
# If your ensemble doesn't have enough topics to begin with, you should make sure to make it large enough.
#
# Having an epsilon that is smaller than the smallest distance doesn't make sense.
# Make sure to chose one that is within the range of values in ``asymmetric_distance_matrix``.

# %%
import numpy as np
shape = ensemble.asymmetric_distance_matrix.shape
without_diagonal = ensemble.asymmetric_distance_matrix[~np.eye(shape[0], dtype=bool)].reshape(shape[0], -1)
print(without_diagonal.min(), without_diagonal.mean(), without_diagonal.max())

ensemble.recluster(eps=0.09, min_samples=2, min_cores=2)

print(len(ensemble.get_topics()))

# %% [markdown]
# Increasing the Size
# -------------------
#
# If you have some models lying around that were trained on a corpus based on the same dictionary,
# they are compatible and you can add them to the ensemble.
#
# By setting num_models of the EnsembleLda constructor to 0 you can also create an ensemble that is
# entirely made out of your existing topic models with the following method.
#
# Afterwards the number and quality of stable topics might be different depending on your added topics and parameters.

# %%
from gensim.models import LdaMulticore

model1 = LdaMulticore(
    corpus=corpus,
    id2word=dictionary,
    num_topics=9,
    passes=4,
)

model2 = LdaModel(
    corpus=corpus,
    id2word=dictionary,
    num_topics=11,
    passes=2,
)

# add_model supports various types of input, check out its docstring
ensemble.add_model(model1)
ensemble.add_model(model2)

ensemble.recluster()

print(len(ensemble.ttda))
print(len(ensemble.get_topics()))
